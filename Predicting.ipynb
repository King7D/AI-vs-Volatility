# %%
import pandas as pd
import numpy as np

# 读取CSV文件
file_path = 'Processed_Data/overall/ETH_clustered.csv' 
df = pd.read_csv(file_path)

# 初始化一个字典来存储相同Cluster组的第六个Change数据
cluster_groups = {}

# 遍历数据集，每组取五个数据点
for i in range(0, len(df) - 5):  # 减去5确保至少有六个数据点用于最后一组
    # 前五个数据来自Cluster列
    cluster_group = tuple(df['cluster1'].iloc[i:i+5])
    
    # 第六个数据来自Change列
    sixth_data_change = df['Change'].iloc[i+5]
    
    # 检查这个Cluster组是否已经在字典中
    if cluster_group in cluster_groups:
        # 如果在，将第六个Change数据加入到对应的列表中
        cluster_groups[cluster_group]['changes'].append(sixth_data_change)
        if sixth_data_change > 0:
            cluster_groups[cluster_group]['positive_count'] += 1
    else:
        # 如果不在，创建一个新的键，并将第六个Change数据作为一个列表的元素
        cluster_groups[cluster_group] = {'changes': [sixth_data_change], 'positive_count': 0}
        if sixth_data_change > 0:
            cluster_groups[cluster_group]['positive_count'] = 1

# 计算每个Cluster组第六个Change数据的平均值和正数百分比
results = {}
for cluster_group, data in cluster_groups.items():
    average_change = np.mean(data['changes'])
    positive_percentage = (data['positive_count'] / len(data['changes'])) * 100
    results[cluster_group] = (average_change, positive_percentage, len(data['changes']))

# 过滤count<10的集群组，并按照Positive Change Percentage从大到小排列
filtered_results = {k: v for k, v in results.items() if v[2] >= 10}
sorted_results = sorted(filtered_results.items(), key=lambda x: x[1][1], reverse=True)

# 打印每个Cluster组及其第六个Change数据的平均值、正数百分比和数据点数量
for cluster_group, (average_change, positive_percentage, data_count) in sorted_results:
    print(f"Cluster Group: {cluster_group}, Average Sixth Data Change: {average_change:.2f}, Positive Change Percentage: {positive_percentage:.2f}%, Data Count: {data_count}")
# Out:
# Cluster Group: (0, 0, 2, 1, 2), Average Sixth Data Change: 0.81, Positive Change Percentage: 90.00%, Data Count: 10
# Cluster Group: (1, 2, 2, 1, 2), Average Sixth Data Change: 0.51, Positive Change Percentage: 80.00%, Data Count: 10
# Cluster Group: (1, 0, 1, 2, 2), Average Sixth Data Change: 0.55, Positive Change Percentage: 76.92%, Data Count: 13
# Cluster Group: (1, 1, 2, 0, 2), Average Sixth Data Change: 0.24, Positive Change Percentage: 75.00%, Data Count: 16
# Cluster Group: (2, 1, 2, 1, 2), Average Sixth Data Change: 0.25, Positive Change Percentage: 75.00%, Data Count: 12
# Cluster Group: (2, 1, 0, 1, 2), Average Sixth Data Change: 0.35, Positive Change Percentage: 75.00%, Data Count: 12
# Cluster Group: (1, 2, 2, 2, 1), Average Sixth Data Change: 0.29, Positive Change Percentage: 72.73%, Data Count: 11
# Cluster Group: (1, 0, 2, 0, 1), Average Sixth Data Change: 0.51, Positive Change Percentage: 72.22%, Data Count: 18
# Cluster Group: (0, 2, 1, 2, 1), Average Sixth Data Change: 0.22, Positive Change Percentage: 71.43%, Data Count: 14
# Cluster Group: (2, 0, 1, 1, 2), Average Sixth Data Change: 0.13, Positive Change Percentage: 69.23%, Data Count: 13
# Cluster Group: (1, 2, 1, 1, 2), Average Sixth Data Change: 0.26, Positive Change Percentage: 68.75%, Data Count: 32
# Cluster Group: (2, 2, 0, 1, 1), Average Sixth Data Change: 0.28, Positive Change Percentage: 66.67%, Data Count: 21
# Cluster Group: (1, 1, 0, 2, 0), Average Sixth Data Change: 0.52, Positive Change Percentage: 66.67%, Data Count: 18
# Cluster Group: (1, 2, 0, 2, 1), Average Sixth Data Change: 0.42, Positive Change Percentage: 66.67%, Data Count: 12
# Cluster Group: (0, 1, 1, 0, 2), Average Sixth Data Change: -0.24, Positive Change Percentage: 64.71%, Data Count: 17
# Cluster Group: (2, 1, 0, 1, 0), Average Sixth Data Change: 0.35, Positive Change Percentage: 64.71%, Data Count: 17
# Cluster Group: (2, 1, 1, 2, 1), Average Sixth Data Change: 0.21, Positive Change Percentage: 64.29%, Data Count: 28
# Cluster Group: (2, 1, 0, 0, 1), Average Sixth Data Change: 0.80, Positive Change Percentage: 64.29%, Data Count: 14
# Cluster Group: (2, 0, 1, 2, 1), Average Sixth Data Change: -0.12, Positive Change Percentage: 64.29%, Data Count: 14
# Cluster Group: (1, 2, 2, 1, 1), Average Sixth Data Change: 0.17, Positive Change Percentage: 63.64%, Data Count: 44
# Cluster Group: (1, 1, 1, 0, 2), Average Sixth Data Change: 0.00, Positive Change Percentage: 63.49%, Data Count: 63
# Cluster Group: (1, 2, 2, 0, 1), Average Sixth Data Change: -0.06, Positive Change Percentage: 62.96%, Data Count: 27
# Cluster Group: (1, 0, 1, 1, 2), Average Sixth Data Change: 0.01, Positive Change Percentage: 61.22%, Data Count: 49
# Cluster Group: (2, 1, 2, 1, 0), Average Sixth Data Change: 0.06, Positive Change Percentage: 61.11%, Data Count: 18
# Cluster Group: (2, 2, 2, 0, 1), Average Sixth Data Change: -0.02, Positive Change Percentage: 60.00%, Data Count: 10
# Cluster Group: (1, 0, 0, 2, 0), Average Sixth Data Change: 0.38, Positive Change Percentage: 60.00%, Data Count: 10
# Cluster Group: (1, 0, 2, 0, 0), Average Sixth Data Change: -0.00, Positive Change Percentage: 60.00%, Data Count: 10
# Cluster Group: (1, 0, 0, 0, 0), Average Sixth Data Change: 0.77, Positive Change Percentage: 60.00%, Data Count: 10
# Cluster Group: (1, 2, 1, 2, 1), Average Sixth Data Change: -0.21, Positive Change Percentage: 59.46%, Data Count: 37
# Cluster Group: (2, 1, 1, 0, 1), Average Sixth Data Change: 0.10, Positive Change Percentage: 59.18%, Data Count: 49
# Cluster Group: (1, 0, 1, 1, 0), Average Sixth Data Change: 0.29, Positive Change Percentage: 58.97%, Data Count: 78
# Cluster Group: (2, 1, 2, 0, 1), Average Sixth Data Change: 0.32, Positive Change Percentage: 58.82%, Data Count: 17
# Cluster Group: (0, 0, 2, 0, 1), Average Sixth Data Change: 0.25, Positive Change Percentage: 58.33%, Data Count: 12
# Cluster Group: (2, 0, 1, 1, 1), Average Sixth Data Change: 0.07, Positive Change Percentage: 58.06%, Data Count: 93
# Cluster Group: (0, 1, 1, 2, 1), Average Sixth Data Change: 0.11, Positive Change Percentage: 58.00%, Data Count: 50
# Cluster Group: (0, 1, 1, 2, 0), Average Sixth Data Change: 0.03, Positive Change Percentage: 57.89%, Data Count: 19
# Cluster Group: (1, 1, 1, 2, 0), Average Sixth Data Change: 0.02, Positive Change Percentage: 57.65%, Data Count: 85
# Cluster Group: (1, 1, 0, 1, 2), Average Sixth Data Change: 0.09, Positive Change Percentage: 57.45%, Data Count: 47
# Cluster Group: (0, 1, 1, 2, 2), Average Sixth Data Change: 0.06, Positive Change Percentage: 57.14%, Data Count: 14
# Cluster Group: (1, 1, 1, 1, 2), Average Sixth Data Change: -0.01, Positive Change Percentage: 56.57%, Data Count: 350
# Cluster Group: (1, 1, 2, 2, 2), Average Sixth Data Change: -0.21, Positive Change Percentage: 56.25%, Data Count: 16
# Cluster Group: (1, 1, 2, 0, 0), Average Sixth Data Change: 0.15, Positive Change Percentage: 56.00%, Data Count: 25
# Cluster Group: (1, 1, 0, 0, 2), Average Sixth Data Change: 0.06, Positive Change Percentage: 56.00%, Data Count: 25
# Cluster Group: (1, 1, 0, 2, 1), Average Sixth Data Change: -0.17, Positive Change Percentage: 55.56%, Data Count: 54
# Cluster Group: (1, 1, 2, 2, 1), Average Sixth Data Change: -0.05, Positive Change Percentage: 55.32%, Data Count: 47
# Cluster Group: (0, 0, 2, 1, 1), Average Sixth Data Change: -0.05, Positive Change Percentage: 55.00%, Data Count: 20
# Cluster Group: (2, 1, 1, 1, 1), Average Sixth Data Change: -0.02, Positive Change Percentage: 54.93%, Data Count: 284
# Cluster Group: (1, 1, 1, 2, 1), Average Sixth Data Change: -0.06, Positive Change Percentage: 54.88%, Data Count: 297
# Cluster Group: (0, 2, 1, 1, 0), Average Sixth Data Change: 0.12, Positive Change Percentage: 54.55%, Data Count: 11
# Cluster Group: (0, 1, 0, 0, 1), Average Sixth Data Change: 0.36, Positive Change Percentage: 54.17%, Data Count: 24
# Cluster Group: (1, 1, 2, 1, 1), Average Sixth Data Change: -0.01, Positive Change Percentage: 53.60%, Data Count: 278
# Cluster Group: (2, 1, 1, 1, 2), Average Sixth Data Change: -0.04, Positive Change Percentage: 53.49%, Data Count: 43
# Cluster Group: (1, 1, 1, 2, 2), Average Sixth Data Change: -0.14, Positive Change Percentage: 52.24%, Data Count: 67
# Cluster Group: (1, 2, 1, 1, 1), Average Sixth Data Change: 0.05, Positive Change Percentage: 52.17%, Data Count: 276
# Cluster Group: (0, 2, 1, 0, 1), Average Sixth Data Change: -0.05, Positive Change Percentage: 52.17%, Data Count: 23
# Cluster Group: (1, 0, 0, 1, 0), Average Sixth Data Change: -0.03, Positive Change Percentage: 51.85%, Data Count: 27
# Cluster Group: (2, 1, 2, 1, 1), Average Sixth Data Change: 0.04, Positive Change Percentage: 51.85%, Data Count: 27
# Cluster Group: (0, 1, 1, 1, 1), Average Sixth Data Change: 0.04, Positive Change Percentage: 51.65%, Data Count: 577
# Cluster Group: (1, 1, 0, 1, 1), Average Sixth Data Change: 0.01, Positive Change Percentage: 51.52%, Data Count: 462
# Cluster Group: (1, 1, 0, 0, 0), Average Sixth Data Change: 0.20, Positive Change Percentage: 51.52%, Data Count: 33
# Cluster Group: (1, 1, 2, 0, 1), Average Sixth Data Change: -0.01, Positive Change Percentage: 50.65%, Data Count: 77
# Cluster Group: (1, 0, 0, 1, 1), Average Sixth Data Change: -0.03, Positive Change Percentage: 50.51%, Data Count: 99
# Cluster Group: (0, 0, 1, 1, 1), Average Sixth Data Change: 0.01, Positive Change Percentage: 50.00%, Data Count: 120
# Cluster Group: (1, 2, 1, 0, 1), Average Sixth Data Change: 0.09, Positive Change Percentage: 50.00%, Data Count: 60
# Cluster Group: (0, 2, 2, 1, 1), Average Sixth Data Change: 0.08, Positive Change Percentage: 50.00%, Data Count: 12
# Cluster Group: (2, 1, 1, 2, 0), Average Sixth Data Change: -0.37, Positive Change Percentage: 50.00%, Data Count: 14
# Cluster Group: (1, 0, 2, 1, 0), Average Sixth Data Change: 0.01, Positive Change Percentage: 50.00%, Data Count: 12
# Cluster Group: (1, 2, 1, 2, 2), Average Sixth Data Change: 0.10, Positive Change Percentage: 50.00%, Data Count: 18
# Cluster Group: (2, 2, 1, 0, 1), Average Sixth Data Change: -0.08, Positive Change Percentage: 50.00%, Data Count: 20
# Cluster Group: (1, 0, 2, 1, 2), Average Sixth Data Change: -0.03, Positive Change Percentage: 50.00%, Data Count: 12
# Cluster Group: (1, 1, 1, 1, 1), Average Sixth Data Change: -0.01, Positive Change Percentage: 49.67%, Data Count: 7512
# Cluster Group: (0, 1, 2, 1, 1), Average Sixth Data Change: 0.21, Positive Change Percentage: 48.89%, Data Count: 45
# Cluster Group: (1, 1, 2, 1, 2), Average Sixth Data Change: -0.29, Positive Change Percentage: 48.84%, Data Count: 43
# Cluster Group: (0, 1, 1, 1, 2), Average Sixth Data Change: -0.14, Positive Change Percentage: 48.21%, Data Count: 56
# Cluster Group: (2, 0, 1, 0, 1), Average Sixth Data Change: 0.02, Positive Change Percentage: 48.00%, Data Count: 25
# Cluster Group: (1, 0, 2, 1, 1), Average Sixth Data Change: -0.02, Positive Change Percentage: 47.83%, Data Count: 46
# Cluster Group: (0, 1, 0, 1, 0), Average Sixth Data Change: 0.03, Positive Change Percentage: 47.62%, Data Count: 21
# Cluster Group: (1, 0, 1, 2, 1), Average Sixth Data Change: -0.09, Positive Change Percentage: 47.62%, Data Count: 42
# Cluster Group: (1, 1, 0, 0, 1), Average Sixth Data Change: 0.02, Positive Change Percentage: 47.42%, Data Count: 97
# Cluster Group: (1, 0, 1, 2, 0), Average Sixth Data Change: 0.31, Positive Change Percentage: 47.37%, Data Count: 19
# Cluster Group: (2, 1, 0, 1, 1), Average Sixth Data Change: -0.01, Positive Change Percentage: 47.30%, Data Count: 74
# Cluster Group: (0, 2, 0, 1, 0), Average Sixth Data Change: 0.14, Positive Change Percentage: 46.67%, Data Count: 15
# Cluster Group: (0, 1, 0, 1, 2), Average Sixth Data Change: -0.13, Positive Change Percentage: 46.67%, Data Count: 15
# Cluster Group: (0, 1, 0, 1, 1), Average Sixth Data Change: 0.00, Positive Change Percentage: 46.24%, Data Count: 93
# Cluster Group: (2, 0, 1, 0, 0), Average Sixth Data Change: 0.16, Positive Change Percentage: 46.15%, Data Count: 13
# Cluster Group: (0, 1, 0, 0, 2), Average Sixth Data Change: 0.09, Positive Change Percentage: 46.15%, Data Count: 13
# Cluster Group: (0, 0, 1, 2, 1), Average Sixth Data Change: -0.05, Positive Change Percentage: 46.15%, Data Count: 13
# Cluster Group: (1, 2, 0, 1, 1), Average Sixth Data Change: -0.06, Positive Change Percentage: 45.78%, Data Count: 83
# Cluster Group: (0, 2, 1, 1, 1), Average Sixth Data Change: -0.17, Positive Change Percentage: 45.61%, Data Count: 57
# Cluster Group: (0, 1, 0, 0, 0), Average Sixth Data Change: -0.14, Positive Change Percentage: 45.45%, Data Count: 11
# Cluster Group: (2, 2, 2, 1, 0), Average Sixth Data Change: -0.12, Positive Change Percentage: 45.45%, Data Count: 11
# Cluster Group: (1, 2, 0, 1, 0), Average Sixth Data Change: 0.03, Positive Change Percentage: 45.00%, Data Count: 20
# Cluster Group: (1, 1, 2, 1, 0), Average Sixth Data Change: 0.07, Positive Change Percentage: 44.44%, Data Count: 54
# Cluster Group: (1, 0, 1, 1, 1), Average Sixth Data Change: -0.04, Positive Change Percentage: 44.42%, Data Count: 502
# Cluster Group: (0, 0, 0, 1, 1), Average Sixth Data Change: -0.12, Positive Change Percentage: 44.19%, Data Count: 43
# Cluster Group: (0, 1, 1, 0, 1), Average Sixth Data Change: -0.04, Positive Change Percentage: 44.16%, Data Count: 77
# Cluster Group: (1, 1, 1, 1, 0), Average Sixth Data Change: 0.03, Positive Change Percentage: 44.03%, Data Count: 511
# Cluster Group: (1, 0, 0, 2, 1), Average Sixth Data Change: -0.02, Positive Change Percentage: 44.00%, Data Count: 25
# Cluster Group: (1, 1, 1, 0, 1), Average Sixth Data Change: -0.03, Positive Change Percentage: 43.04%, Data Count: 460
# Cluster Group: (1, 2, 0, 0, 1), Average Sixth Data Change: 0.18, Positive Change Percentage: 42.86%, Data Count: 21
# Cluster Group: (0, 1, 2, 0, 1), Average Sixth Data Change: -0.05, Positive Change Percentage: 42.86%, Data Count: 21
# Cluster Group: (1, 1, 1, 0, 0), Average Sixth Data Change: -0.00, Positive Change Percentage: 42.50%, Data Count: 120
# Cluster Group: (2, 0, 2, 1, 1), Average Sixth Data Change: -0.21, Positive Change Percentage: 41.67%, Data Count: 12
# Cluster Group: (1, 2, 0, 1, 2), Average Sixth Data Change: -0.53, Positive Change Percentage: 41.67%, Data Count: 12
# Cluster Group: (0, 1, 1, 1, 0), Average Sixth Data Change: 0.09, Positive Change Percentage: 41.46%, Data Count: 82
# Cluster Group: (1, 0, 1, 0, 1), Average Sixth Data Change: -0.05, Positive Change Percentage: 40.96%, Data Count: 83
# Cluster Group: (1, 2, 1, 1, 0), Average Sixth Data Change: -0.12, Positive Change Percentage: 40.48%, Data Count: 42
# Cluster Group: (0, 2, 1, 1, 2), Average Sixth Data Change: -0.29, Positive Change Percentage: 40.00%, Data Count: 10
# Cluster Group: (2, 1, 1, 1, 0), Average Sixth Data Change: -0.03, Positive Change Percentage: 40.00%, Data Count: 50
# Cluster Group: (2, 1, 2, 2, 0), Average Sixth Data Change: -0.41, Positive Change Percentage: 40.00%, Data Count: 10
# Cluster Group: (0, 0, 0, 0, 1), Average Sixth Data Change: -0.30, Positive Change Percentage: 40.00%, Data Count: 10
# Cluster Group: (0, 2, 0, 1, 1), Average Sixth Data Change: 0.06, Positive Change Percentage: 40.00%, Data Count: 20
# Cluster Group: (0, 0, 1, 1, 0), Average Sixth Data Change: -0.28, Positive Change Percentage: 40.00%, Data Count: 25
# Cluster Group: (2, 2, 1, 1, 1), Average Sixth Data Change: -0.15, Positive Change Percentage: 38.64%, Data Count: 44
# Cluster Group: (1, 2, 1, 2, 0), Average Sixth Data Change: -0.16, Positive Change Percentage: 38.46%, Data Count: 13
# Cluster Group: (0, 1, 2, 1, 2), Average Sixth Data Change: -0.96, Positive Change Percentage: 38.46%, Data Count: 13
# Cluster Group: (0, 0, 1, 1, 2), Average Sixth Data Change: -0.12, Positive Change Percentage: 38.10%, Data Count: 21
# Cluster Group: (1, 1, 0, 1, 0), Average Sixth Data Change: 0.05, Positive Change Percentage: 37.66%, Data Count: 77
# Cluster Group: (2, 0, 0, 1, 1), Average Sixth Data Change: -0.03, Positive Change Percentage: 37.50%, Data Count: 24
# Cluster Group: (1, 1, 0, 2, 2), Average Sixth Data Change: -0.43, Positive Change Percentage: 37.50%, Data Count: 16
# Cluster Group: (1, 2, 0, 0, 0), Average Sixth Data Change: -0.12, Positive Change Percentage: 36.36%, Data Count: 11
# Cluster Group: (0, 1, 2, 2, 1), Average Sixth Data Change: -0.08, Positive Change Percentage: 36.36%, Data Count: 11
# Cluster Group: (1, 0, 1, 0, 0), Average Sixth Data Change: -0.01, Positive Change Percentage: 36.00%, Data Count: 25
# Cluster Group: (0, 0, 1, 0, 1), Average Sixth Data Change: -0.20, Positive Change Percentage: 33.33%, Data Count: 21
# Cluster Group: (2, 0, 1, 1, 0), Average Sixth Data Change: -0.59, Positive Change Percentage: 33.33%, Data Count: 18
# Cluster Group: (0, 2, 0, 0, 1), Average Sixth Data Change: -0.31, Positive Change Percentage: 33.33%, Data Count: 12
# Cluster Group: (0, 1, 1, 0, 0), Average Sixth Data Change: -0.28, Positive Change Percentage: 33.33%, Data Count: 27
# Cluster Group: (1, 2, 2, 1, 0), Average Sixth Data Change: -0.30, Positive Change Percentage: 30.77%, Data Count: 13
# Cluster Group: (1, 2, 0, 2, 0), Average Sixth Data Change: -0.81, Positive Change Percentage: 30.00%, Data Count: 10
# Cluster Group: (2, 0, 2, 0, 1), Average Sixth Data Change: 0.03, Positive Change Percentage: 30.00%, Data Count: 10
# Cluster Group: (2, 0, 0, 1, 0), Average Sixth Data Change: 0.06, Positive Change Percentage: 30.00%, Data Count: 10
# Cluster Group: (1, 1, 2, 2, 0), Average Sixth Data Change: 0.31, Positive Change Percentage: 29.17%, Data Count: 24
# Cluster Group: (1, 0, 0, 0, 1), Average Sixth Data Change: -0.06, Positive Change Percentage: 29.03%, Data Count: 31
# Cluster Group: (1, 2, 1, 0, 0), Average Sixth Data Change: -0.27, Positive Change Percentage: 28.57%, Data Count: 14
# Cluster Group: (0, 1, 2, 1, 0), Average Sixth Data Change: -0.40, Positive Change Percentage: 27.27%, Data Count: 11
# Cluster Group: (2, 0, 0, 0, 1), Average Sixth Data Change: -0.39, Positive Change Percentage: 25.00%, Data Count: 12
# Cluster Group: (0, 0, 1, 0, 0), Average Sixth Data Change: -0.33, Positive Change Percentage: 20.00%, Data Count: 10
# Cluster Group: (2, 2, 1, 1, 0), Average Sixth Data Change: -0.56, Positive Change Percentage: 16.67%, Data Count: 12
